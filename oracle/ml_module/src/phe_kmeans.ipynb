# %%
import phe as paillier
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
import sklearn as sk
from sklearn.cluster import KMeans

# %%
pubkey, privkey = paillier.generate_paillier_keypair(n_length=1024)
df = pd.read_csv('online_retail.csv')
df.convert_objects(convert_numeric=True)
df.fillna(0, inplace=True)
df.head()
# Out:
# /home/lee/dev/school_project/src/oracle/ml_module/lib/python3.5/site-packages/ipykernel_launcher.py:3: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   This is separate from the ipykernel package so we can avoid doing imports until
#   StockCode                          Description  Quantity  UnitPrice  \
# 0    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6       2.55
# 1     71053                  WHITE METAL LANTERN         6       3.39
# 2    84406B       CREAM CUPID HEARTS COAT HANGER         8       2.75
# 3    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6       3.39
# 4    84029E       RED WOOLLY HOTTIE WHITE HEART.         6       3.39
#
#    CustomerID
# 0     17850.0
# 1     17850.0
# 2     17850.0
# 3     17850.0
# 4     17850.0

# %%
def handle_non_numeric_data(df):
    columns = df.columns.values
    
    for column in columns:
        text_digit_vals = {}
        def convert_to_int(val):
            return text_digit_vals[val]
        
        if df[column].dtype != np.int64 and df[column].dtype != np.float64:
            column_contents = df[column].values.tolist()
            unique_elements = set(column_contents)
            
            x = 0
            
            for unique in unique_elements:
                if unique not in text_digit_vals:
                    text_digit_vals[unique] = x
                    x += 1
            
            df[column] = list(map(convert_to_int, df[column]))
            
    return df

df = handle_non_numeric_data(df)
df.head()
# Out:
#    StockCode  Description  Quantity  UnitPrice  CustomerID
# 0        764          918         6       2.55     17850.0
# 1        292           71         6       3.39     17850.0
# 2        879          398         8       2.75     17850.0
# 3        461          884         6       3.39     17850.0
# 4        703          523         6       3.39     17850.0

# %%
for index, row in df.iterrows():
    temp = df[row].values.tolist()
    temp = [pubkey.encrypt(x) for x in temp]
    print (temp[0].ciphertext())
#     for column in df.columns:
#         pubkey.encrypt(row[column])
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-2d7cf1f34c5c> in <module>
#       1 for index, row in df.iterrows():
# ----> 2     temp = df[row].values.tolist()
#       3     temp = [pubkey.encrypt(x) for x in temp]
#       4     print (temp[0].ciphertext())
#       5 #     for column in df.columns:
#
# ~/dev/school_project/src/oracle/ml_module/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/dev/school_project/src/oracle/ml_module/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ~/dev/school_project/src/oracle/ml_module/lib/python3.5/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: '[7.640e+02 9.180e+02 6.000e+00 2.550e+00 1.785e+04] not in index'
